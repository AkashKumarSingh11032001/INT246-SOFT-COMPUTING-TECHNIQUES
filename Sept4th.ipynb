# %%
import numpy as  
import matplotlib.pyplot as plt
x = np.arange(-10,10)
y = x
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,100)
y = []
for i in range(0,100):
    if(x[i] >= 50):
        y.append(1)
    else:
        y.append(0)
plt.plot(x,y)
plt.show()
